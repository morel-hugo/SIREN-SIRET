# %%
import pandas as pd
import seaborn as sns
import numpy as np
import math
from datetime import *
import pygal             # Usefull for french map
from pygal.style import Style
import matplotlib.pyplot as plt
import requests
import json
import csv

# %matplotlib inline

# %% [markdown]
# ### Import Data

# %%
df = pd.read_csv('data.csv')
df.head(10)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3049: DtypeWarning: Columns (8,26,27,28,30,33,34,43,73) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    Unnamed: 0    siren  nic         siret statutDiffusionEtablissement  \
# 0           0  1807254   14  180725400014                            O
# 1           1  5410220   15  541022000015                            O
# 2           2  5410345   10  541034500010                            O
# 3           3  5410394   18  541039400018                            O
# 4           4  5410428   14  541042800014                            O
# 5           5  5410436   17  541043600017                            O
# 6           6  5410485   14  541048500014                            O
# 7           7  5410527   13  541052700013                            O
# 8           8  5410642   10  541064200010                            O
# 9           9  5410667   17  541066700017                            O
#
#   dateCreationEtablissement trancheEffectifsEtablissement  \
# 0                1972-05-01                           NaN
# 1                       NaN                            NN
# 2                       NaN                           NaN
# 3                       NaN                            NN
# 4                1954-01-01                            NN
# 5                       NaN                           NaN
# 6                       NaN                           NaN
# 7                       NaN                           NaN
# 8                       NaN                            NN
# 9                       NaN                            NN
#
#    anneeEffectifsEtablissement activitePrincipaleRegistreMetiersEtablissement  \
# 0                          NaN                                            NaN
# 1                          NaN                                            NaN
# 2                          NaN                                            NaN
# 3                          NaN                                            NaN
# 4                          NaN                                            NaN
# 5                          NaN                                            NaN
# 6                          NaN                                            NaN
# 7                          NaN                                            NaN
# 8                          NaN                                            NaN
# 9                          NaN                                            NaN
#
#   dateDernierTraitementEtablissement  ...   dateDebut  \
# 0                2009-10-02T11:01:38  ...  1978-05-31
# 1                                NaN  ...  1988-03-31
# 2                                NaN  ...  1984-12-25
# 3                                NaN  ...  1987-12-01
# 4                                NaN  ...  1989-06-11
# 5                                NaN  ...  1984-12-25
# 6                                NaN  ...  1985-12-25
# 7                                NaN  ...  1997-07-01
# 8                                NaN  ...  1991-12-31
# 9                                NaN  ...  1996-10-30
#
#    etatAdministratifEtablissement enseigne1Etablissement  \
# 0                               F                    NaN
# 1                               F                    NaN
# 2                               F                    NaN
# 3                               F                    NaN
# 4                               F                    NaN
# 5                               F                    NaN
# 6                               F                    NaN
# 7                               F                    NaN
# 8                               F                    NaN
# 9                               F                    NaN
#
#   enseigne2Etablissement enseigne3Etablissement  \
# 0                    NaN                    NaN
# 1                    NaN                    NaN
# 2                    NaN                    NaN
# 3                    NaN                    NaN
# 4                    NaN                    NaN
# 5                    NaN                    NaN
# 6                    NaN                    NaN
# 7                    NaN                    NaN
# 8                    NaN                    NaN
# 9                    NaN                    NaN
#
#   denominationUsuelleEtablissement  activitePrincipaleEtablissement  \
# 0                              NaN                              NaN
# 1                              NaN                            22.02
# 2                              NaN                            79.06
# 3                              NaN                            64.42
# 4                              NaN                            70.2C
# 5                              NaN                            57.11
# 6                              NaN                            64.42
# 7                              NaN                            70.2C
# 8                              NaN                            64.45
# 9                              NaN                            55.4B
#
#   nomenclatureActivitePrincipaleEtablissement caractereEmployeurEtablissement  \
# 0                                         NaN                               N
# 1                                         NAP                               N
# 2                                         NAP                               N
# 3                                         NAP                               N
# 4                                     NAF1993                               N
# 5                                         NAP                               N
# 6                                         NAP                               N
# 7                                     NAF1993                               N
# 8                                         NAP                               N
# 9                                     NAF1993                               O
#
#   codeDepartement
# 0              54
# 1              80
# 2              80
# 3              80
# 4              80
# 5              80
# 6              80
# 7              80
# 8              80
# 9              80
#
# [10 rows x 81 columns]

# %% [markdown]
# ### Load Code and Name

# %%
a = pd.read_excel('code_naf2.xlsx')

# %% [markdown]
# # 1) Density By Sector of Activity

# %% [markdown]
# ### Selection

# %%
sector = '55.4B'

# %%
df_selection = df[(df['activitePrincipaleEtablissement'] == sector)].groupby('codeDepartement').count()

# %%
df_selection.head()
# Out:
#                  Unnamed: 0  siren  nic  siret  statutDiffusionEtablissement  \
# codeDepartement
# 35                        1      1    1      1                             1
# 40                       11     11   11     11                            11
# 41                        4      4    4      4                             4
# 42                        3      3    3      3                             3
# 44                       40     40   40     40                            40
#
#                  dateCreationEtablissement  trancheEffectifsEtablissement  \
# codeDepartement
# 35                                       0                              1
# 40                                       7                              8
# 41                                       4                              4
# 42                                       2                              3
# 44                                      14                             36
#
#                  anneeEffectifsEtablissement  \
# codeDepartement
# 35                                         0
# 40                                         1
# 41                                         0
# 42                                         0
# 44                                         0
#
#                  activitePrincipaleRegistreMetiersEtablissement  \
# codeDepartement
# 35                                                            0
# 40                                                            0
# 41                                                            0
# 42                                                            0
# 44                                                            0
#
#                  dateDernierTraitementEtablissement  ...  dateFin  dateDebut  \
# codeDepartement                                      ...
# 35                                                0  ...        0          1
# 40                                                4  ...        4         11
# 41                                                2  ...        2          4
# 42                                                1  ...        1          3
# 44                                                8  ...        7         40
#
#                  etatAdministratifEtablissement  enseigne1Etablissement  \
# codeDepartement
# 35                                            1                       0
# 40                                           10                       0
# 41                                            4                       0
# 42                                            3                       0
# 44                                           40                       1
#
#                  enseigne2Etablissement  enseigne3Etablissement  \
# codeDepartement
# 35                                    0                       0
# 40                                    0                       0
# 41                                    0                       0
# 42                                    0                       0
# 44                                    0                       0
#
#                  denominationUsuelleEtablissement  \
# codeDepartement
# 35                                              0
# 40                                              0
# 41                                              0
# 42                                              0
# 44                                              0
#
#                  activitePrincipaleEtablissement  \
# codeDepartement
# 35                                             1
# 40                                            11
# 41                                             4
# 42                                             3
# 44                                            40
#
#                  nomenclatureActivitePrincipaleEtablissement  \
# codeDepartement
# 35                                                         1
# 40                                                        11
# 41                                                         4
# 42                                                         3
# 44                                                        40
#
#                  caractereEmployeurEtablissement
# codeDepartement
# 35                                             1
# 40                                             9
# 41                                             4
# 42                                             3
# 44                                            40
#
# [5 rows x 80 columns]

# %% [markdown]
# ### French map : Use Librairie PYGAL

# %%
custom_style = Style(
  background='transparent',
  transition='200ms ease-in',
)

# %%
name_code_naf = a.loc[a['code'] == sector]

# %%
name_code_naf = name_code_naf.iloc[0,1]

# %%
name_code_naf
# Out:
# 'Débits de boissons'

# %%
def chart():
    fr_chart = pygal.maps.fr.Departments(style=custom_style,height=450,human_readable=True)    #,legend_at_bottom=True)
    fr_chart.title = 'Density by Sector of Activity'
    fr_chart.add(name_code_naf, {x for x in zip(df_selection.index ,df_selection['siren'])})
    fr_chart.render_in_browser() # Exporte to Browser

# %%
chart()
# Out:
# file:///var/folders/v3/6rms4ljn2dzdln_l8746trf00000gn/T/tmpjjgewf45.html

# %% [markdown]
# # 2) Density of population by Departement

# %% [markdown]
# ### Import Datas

# %%
df_pop = pd.read_csv('pop_2019.csv')

# %%
df_pop.head()
# Out:
#    Unnamed: 0  code     pop
# 0           0     1  653688
# 1           1     2  528016
# 2           2     3  333065
# 3           3     4  161980
# 4           4     5  141784

# %% [markdown]
# ### French map : Use Librairie PYGAL

# %%
custom_style = Style(
  background='transparent',
  transition='200ms ease-in',
)

# %%
def chart():
    fr_chart = pygal.maps.fr.Departments(style=custom_style,height=450,human_readable=True)    #,legend_at_bottom=True)
    fr_chart.title = 'Population Density'
    fr_chart.add('In 2019', {x for x in zip(df_pop['code'] ,df_pop['pop'])})
    fr_chart.render_in_browser() # Exporte to Browser

# %%
chart()
# Out:
# file:///var/folders/v3/6rms4ljn2dzdln_l8746trf00000gn/T/tmpxu252s6b.html

# %% [markdown]
# ## 3) Ratio Nombre d'habitant/ Nombre D'entreprise

# %% [markdown]
# ### Create Ratio

# %%
ratio_list = list()
for val,val2 in zip(df_selection.index,df_selection['siren']):
    for val3,val4 in zip(df_pop['code'] ,df_pop['pop']):
        if val == val3:
            ratio_list.append((val,val2,val4))

# %%
ratio = list()
for i in range(len(ratio_list)):
    ratio.append((ratio_list[i][0],ratio_list[i][2]/ratio_list[i][1]))

# %% [markdown]
# ### French map : Use Librairie PYGAL

# %%
def chart():
    fr_chart = pygal.maps.fr.Departments(style=custom_style,height=450,human_readable=True)    #,legend_at_bottom=True)
    fr_chart.title = 'Ratio Population/compagnie'
    fr_chart.add('Ratio In 2019', {x for x in ratio})
    fr_chart.render_in_browser() # Exporte to Browser

# %%
chart()
# Out:
# file:///var/folders/v3/6rms4ljn2dzdln_l8746trf00000gn/T/tmp3ut9aj1m.html

# %% [markdown]
# ## 4) Date Close, less 5 years exprerience

# %% [markdown]
# ### Choose time experience

# %%
date_close = 5

# %%
df_selection2 = df[(df['activitePrincipaleEtablissement'] == sector)]

# %% [markdown]
# ### Convert dateDebut and dateFin to Datetime

# %%
df_selection2['dateDebut'] = pd.to_datetime(df_selection2['dateDebut'])
df_selection2['dateFin'] = pd.to_datetime(df_selection2['dateFin'])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# ### Value dateFin null

# %%
df_selection2['dateFin'].isnull().sum()
# Out:
# 62

# %%
count_close = 0
for i in range(len(df)):
    try:
        if not math.isnan(df_selection2['dateFin'][i].year):
            if df_selection2['dateFin'][i].year <= df_selection2['dateDebut'][i].year + date_close:
                count_close += 1
    except:
        pass

# %%
print("Companies close before 5 years experience : ", count_close)
# Out:
# Companies close before 5 years experience :  3

# %% [markdown]
# ## 5) Distance 50 Km

# %% [markdown]
# ### Load Data GPS

# %%
gps = pd.read_csv('commune_gps.csv',sep=';',error_bad_lines=False)

# %%
gps
# Out:
#         EU_circo  code_région                nom_région chef-lieu_région  \
# 0        Sud-Est           82               Rhône-Alpes             Lyon
# 1        Sud-Est           82               Rhône-Alpes             Lyon
# 2        Sud-Est           82               Rhône-Alpes             Lyon
# 3        Sud-Est           82               Rhône-Alpes             Lyon
# 4        Sud-Est           82               Rhône-Alpes             Lyon
# 5        Sud-Est           82               Rhône-Alpes             Lyon
# 6        Sud-Est           82               Rhône-Alpes             Lyon
# 7        Sud-Est           82               Rhône-Alpes             Lyon
# 8        Sud-Est           82               Rhône-Alpes             Lyon
# 9        Sud-Est           82               Rhône-Alpes             Lyon
# 10       Sud-Est           82               Rhône-Alpes             Lyon
# 11       Sud-Est           82               Rhône-Alpes             Lyon
# 12       Sud-Est           82               Rhône-Alpes             Lyon
# 13       Sud-Est           82               Rhône-Alpes             Lyon
# 14       Sud-Est           82               Rhône-Alpes             Lyon
# 15       Sud-Est           82               Rhône-Alpes             Lyon
# 16       Sud-Est           82               Rhône-Alpes             Lyon
# 17       Sud-Est           82               Rhône-Alpes             Lyon
# 18       Sud-Est           82               Rhône-Alpes             Lyon
# 19       Sud-Est           82               Rhône-Alpes             Lyon
# 20       Sud-Est           82               Rhône-Alpes             Lyon
# 21       Sud-Est           82               Rhône-Alpes             Lyon
# 22       Sud-Est           82               Rhône-Alpes             Lyon
# 23       Sud-Est           82               Rhône-Alpes             Lyon
# 24       Sud-Est           82               Rhône-Alpes             Lyon
# 25       Sud-Est           82               Rhône-Alpes             Lyon
# 26       Sud-Est           82               Rhône-Alpes             Lyon
# 27       Sud-Est           82               Rhône-Alpes             Lyon
# 28       Sud-Est           82               Rhône-Alpes             Lyon
# 29       Sud-Est           82               Rhône-Alpes             Lyon
# ...          ...          ...                       ...              ...
# 36810  Outre-Mer            4                La Réunion      Saint-Denis
# 36811  Outre-Mer            4                La Réunion      Saint-Denis
# 36812  Outre-Mer            4                La Réunion      Saint-Denis
# 36813  Outre-Mer            4                La Réunion      Saint-Denis
# 36814  Outre-Mer            4                La Réunion      Saint-Denis
# 36815  Outre-Mer            4                La Réunion      Saint-Denis
# 36816  Outre-Mer            4                La Réunion      Saint-Denis
# 36817  Outre-Mer            4                La Réunion      Saint-Denis
# 36818  Outre-Mer            4                La Réunion      Saint-Denis
# 36819  Outre-Mer            4                La Réunion      Saint-Denis
# 36820  Outre-Mer            4                La Réunion      Saint-Denis
# 36821  Outre-Mer            4                La Réunion      Saint-Denis
# 36822  Outre-Mer            6  Saint-Pierre-et-Miquelon     Saint-Pierre
# 36823  Outre-Mer            6  Saint-Pierre-et-Miquelon     Saint-Pierre
# 36824  Outre-Mer            6  Saint-Pierre-et-Miquelon     Saint-Pierre
# 36825  Outre-Mer            6  Saint-Pierre-et-Miquelon     Saint-Pierre
# 36826  Outre-Mer            5                   Mayotte        Mamoudzou
# 36827  Outre-Mer            5                   Mayotte        Mamoudzou
# 36828  Outre-Mer            5                   Mayotte        Mamoudzou
# 36829  Outre-Mer            5                   Mayotte        Mamoudzou
# 36830  Outre-Mer            5                   Mayotte        Mamoudzou
# 36831  Outre-Mer            5                   Mayotte        Mamoudzou
# 36832  Outre-Mer            5                   Mayotte        Mamoudzou
# 36833  Outre-Mer            5                   Mayotte        Mamoudzou
# 36834  Outre-Mer            5                   Mayotte        Mamoudzou
# 36835  Outre-Mer            5                   Mayotte        Mamoudzou
# 36836  Outre-Mer            5                   Mayotte        Mamoudzou
# 36837  Outre-Mer            5                   Mayotte        Mamoudzou
# 36838  Outre-Mer            5                   Mayotte        Mamoudzou
# 36839  Outre-Mer            5                   Mayotte        Mamoudzou
#
#       numéro_département           nom_département       préfecture  \
# 0                     01                       Ain  Bourg-en-Bresse
# 1                     01                       Ain  Bourg-en-Bresse
# 2                     01                       Ain  Bourg-en-Bresse
# 3                     01                       Ain  Bourg-en-Bresse
# 4                     01                       Ain  Bourg-en-Bresse
# 5                     01                       Ain  Bourg-en-Bresse
# 6                     01                       Ain  Bourg-en-Bresse
# 7                     01                       Ain  Bourg-en-Bresse
# 8                     01                       Ain  Bourg-en-Bresse
# 9                     01                       Ain  Bourg-en-Bresse
# 10                    01                       Ain  Bourg-en-Bresse
# 11                    01                       Ain  Bourg-en-Bresse
# 12                    01                       Ain  Bourg-en-Bresse
# 13                    01                       Ain  Bourg-en-Bresse
# 14                    01                       Ain  Bourg-en-Bresse
# 15                    01                       Ain  Bourg-en-Bresse
# 16                    01                       Ain  Bourg-en-Bresse
# 17                    01                       Ain  Bourg-en-Bresse
# 18                    01                       Ain  Bourg-en-Bresse
# 19                    01                       Ain  Bourg-en-Bresse
# 20                    01                       Ain  Bourg-en-Bresse
# 21                    01                       Ain  Bourg-en-Bresse
# 22                    01                       Ain  Bourg-en-Bresse
# 23                    01                       Ain  Bourg-en-Bresse
# 24                    01                       Ain  Bourg-en-Bresse
# 25                    01                       Ain  Bourg-en-Bresse
# 26                    01                       Ain  Bourg-en-Bresse
# 27                    01                       Ain  Bourg-en-Bresse
# 28                    01                       Ain  Bourg-en-Bresse
# 29                    01                       Ain  Bourg-en-Bresse
# ...                  ...                       ...              ...
# 36810                974                   Réunion      Saint-Denis
# 36811                974                   Réunion      Saint-Denis
# 36812                974                   Réunion      Saint-Denis
# 36813                974                   Réunion      Saint-Denis
# 36814                974                   Réunion      Saint-Denis
# 36815                974                   Réunion      Saint-Denis
# 36816                974                   Réunion      Saint-Denis
# 36817                974                   Réunion      Saint-Denis
# 36818                974                   Réunion      Saint-Denis
# 36819                974                   Réunion      Saint-Denis
# 36820                974                   Réunion      Saint-Denis
# 36821                974                   Réunion      Saint-Denis
# 36822                975  Saint-Pierre-et-Miquelon     Saint-Pierre
# 36823                975  Saint-Pierre-et-Miquelon     Saint-Pierre
# 36824                975  Saint-Pierre-et-Miquelon     Saint-Pierre
# 36825                975  Saint-Pierre-et-Miquelon     Saint-Pierre
# 36826                976                   Mayotte        Mamoudzou
# 36827                976                   Mayotte        Mamoudzou
# 36828                976                   Mayotte        Mamoudzou
# 36829                976                   Mayotte        Mamoudzou
# 36830                976                   Mayotte        Mamoudzou
# 36831                976                   Mayotte        Mamoudzou
# 36832                976                   Mayotte        Mamoudzou
# 36833                976                   Mayotte        Mamoudzou
# 36834                976                   Mayotte        Mamoudzou
# 36835                976                   Mayotte        Mamoudzou
# 36836                976                   Mayotte        Mamoudzou
# 36837                976                   Mayotte        Mamoudzou
# 36838                976                   Mayotte        Mamoudzou
# 36839                976                   Mayotte        Mamoudzou
#
#        numéro_circonscription              nom_commune codes_postaux  \
# 0                           1                 Attignat         01340
# 1                           1                 Beaupont         01270
# 2                           1                     Bény         01370
# 3                           1                Béreyziat         01340
# 4                           1     Bohas-Meyriat-Rignat         01250
# 5                           1          Bourg-en-Bresse         01000
# 6                           1                  Buellas         01310
# 7                           1                 Certines         01240
# 8                           1                Ceyzériat         01250
# 9                           1      Chavannes-sur-Suran         01250
# 10                          1                     Cize         01250
# 11                          1                  Coligny         01270
# 12                          1               Confrançon         01310
# 13                          1                   Cormoz         01560
# 14                          1              Corveissiat         01250
# 15                          1              Courmangoux         01370
# 16                          1                  Courtes         01560
# 17                          1       Cras-sur-Reyssouze         01340
# 18                          1         Curciat-Dongalon         01560
# 19                          1                Curtafond         01310
# 20                          1      Dompierre-sur-Veyle         01240
# 21                          1                  Domsure         01270
# 22                          1                     Drom         01250
# 23                          1                 Druillat         01160
# 24                          1                    Etrez         01340
# 25                          1                 Foissiat         01340
# 26                          1                Germagnat         01250
# 27                          1             Grand-Corent         01250
# 28                          1     Hautecourt-Romanèche         01250
# 29                          1                 Jasseron         01250
# ...                       ...                      ...           ...
# 36810                       4               Petite-Ile         97429
# 36811                       4              Sainte-Rose         97439
# 36812                       4             Saint-Joseph         97480
# 36813                       4           Saint-Philippe         97442
# 36814                       4             Saint-Pierre         97410
# 36815                       5               Bras-Panon         97412
# 36816                       5  La Plaine-des-Palmistes         97431
# 36817                       5              Saint-André         97440
# 36818                       5             Saint-Benoît         97470
# 36819                       5             Sainte-Marie         97438
# 36820                       5           Sainte-Suzanne         97441
# 36821                       5                  Salazie         97433
# 36822                       1                    ACOUA         97500
# 36823                       1               BANDRABOUA         97500
# 36824                       1                 BANDRELE         97500
# 36825                       1             SAINT-PIERRE         97500
# 36826                       1                   BOUÉNI         97600
# 36827                       1                  CHICONI         97600
# 36828                       1                CHIRONGUI         97620
# 36829                       1                  DEMBENI         97660
# 36830                       1                 DZAOUDZI         97610
# 36831                       1                KANI-KÉLI         97625
# 36832                       1                  KOUNGOU         97690
# 36833                       1                MAMOUDZOU         97600
# 36834                       1                MTSAMBORO         97630
# 36835                       1            M'TSANGAMOUJI         97600
# 36836                       1                 OUANGANI         97600
# 36837                       1                 PAMANDZI         97610
# 36838                       1                     SADA         97640
# 36839                       1                 TSINGONI         97600
#
#        code_insee   latitude longitude éloignement
# 0            1024  46.283333  5.166667        1.21
# 1            1029       46.4  5.266667        1.91
# 2            1038  46.333333  5.283333        1.51
# 3            1040  46.366667      5.05        1.71
# 4            1245  46.133333       5.4        1.01
# 5            1053       46.2  5.216667           1
# 6            1065       46.2  5.133333        0.73
# 7            1069  46.133333  5.266667        1.97
# 8            1072  46.166667  5.316667        1.15
# 9            1095  46.266667  5.416667        1.14
# 10           1106       46.2  5.433333        0.72
# 11           1108  46.383333      5.35        1.81
# 12           1115  46.266667  5.066667        1.35
# 13           1124      46.45  5.233333        2.27
# 14           1125  46.233333  5.483333        1.58
# 15           1127  46.333333  5.366667        1.51
# 16           1128  46.466667       5.1        2.31
# 17           1130       46.3  5.166667        1.31
# 18           1139  46.466667      5.15        2.31
# 19           1140  46.266667  5.083333        1.11
# 20           1145  46.066667       5.2        1.13
# 21           1147  46.416667       5.3        2.01
# 22           1150  46.216667  5.366667         0.8
# 23           1151  46.066667  5.316667         0.1
# 24           1154  46.333333  5.183333        1.51
# 25           1163  46.366667  5.183333        1.71
# 26           1172  46.316667      5.45        2.05
# 27           1177       46.2  5.433333        0.72
# 28           1184  46.158333  5.416667          -1
# 29           1195  46.216667  5.333333        0.84
# ...           ...        ...       ...         ...
# 36810       97405        NaN       NaN         NaN
# 36811       97419        NaN       NaN         NaN
# 36812       97412        NaN       NaN         NaN
# 36813       97417        NaN       NaN         NaN
# 36814       97416        NaN       NaN         NaN
# 36815       97402        NaN       NaN         NaN
# 36816       97406        NaN       NaN         NaN
# 36817       97409        NaN       NaN         NaN
# 36818       97410        NaN       NaN         NaN
# 36819       97418        NaN       NaN         NaN
# 36820       97420        NaN       NaN         NaN
# 36821       97421        NaN       NaN         NaN
# 36822       97501        NaN       NaN         NaN
# 36823       97502        NaN       NaN         NaN
# 36824       97503        NaN       NaN         NaN
# 36825       97502        NaN       NaN         NaN
# 36826       97604        NaN       NaN         NaN
# 36827       97605        NaN       NaN         NaN
# 36828       97606        NaN       NaN         NaN
# 36829       97607        NaN       NaN         NaN
# 36830       97608        NaN       NaN         NaN
# 36831       97609        NaN       NaN         NaN
# 36832       97610        NaN       NaN         NaN
# 36833       97611        NaN       NaN         NaN
# 36834       97612        NaN       NaN         NaN
# 36835       97613        NaN       NaN         NaN
# 36836       97614        NaN       NaN         NaN
# 36837       97615        NaN       NaN         NaN
# 36838       97616        NaN       NaN         NaN
# 36839       97617        NaN       NaN         NaN
#
# [36840 rows x 14 columns]

# %% [markdown]
# ### Select Siret

# %%
siret = 1451659500015

# %% [markdown]
# ### Select Row from Siret

# %%
df_gps = df.loc[df['siret'] == siret]
df_gps['activitePrincipaleEtablissement']
# Out:
# 9999    70.3C
# Name: activitePrincipaleEtablissement, dtype: object

# %% [markdown]
# ### Select Activity

# %%
activity = df_gps.iloc[0,77]
activity
# Out:
# '70.3C'

# %% [markdown]
# ### Select codeCommune

# %%
codeCommune = int(df_gps.iloc[0,51])
codeCommune
# Out:
# 90010

# %% [markdown]
# ### Select Latitude

# %%
df_latitude_longitude = gps.loc[gps['code_insee'] == codeCommune]
lalitude = df_latitude_longitude.iloc[0,11]
lalitude
# Out:
# '47.633333'

# %% [markdown]
# ### Select Longitude

# %%
longitude = df_latitude_longitude.iloc[0,12]
longitude
# Out:
# '6.866667'

# %% [markdown]
# ### Find Latitude Longitude other Commune

# %%
df_selection2 = df[(df['activitePrincipaleEtablissement'] == activity)].groupby('codeCommuneEtablissement').count()
df_selection2.head()
# Out:
#                           Unnamed: 0  siren  nic  siret  \
# codeCommuneEtablissement
# 8043.0                             1      1    1      1
# 8105.0                            62     62   62     62
# 8142.0                             1      1    1      1
# 8362.0                             8      8    8      8
# 8409.0                             9      9    9      9
#
#                           statutDiffusionEtablissement  \
# codeCommuneEtablissement
# 8043.0                                               1
# 8105.0                                              62
# 8142.0                                               1
# 8362.0                                               8
# 8409.0                                               9
#
#                           dateCreationEtablissement  \
# codeCommuneEtablissement
# 8043.0                                            1
# 8105.0                                           62
# 8142.0                                            1
# 8362.0                                            8
# 8409.0                                            8
#
#                           trancheEffectifsEtablissement  \
# codeCommuneEtablissement
# 8043.0                                                1
# 8105.0                                               57
# 8142.0                                                1
# 8362.0                                                8
# 8409.0                                                9
#
#                           anneeEffectifsEtablissement  \
# codeCommuneEtablissement
# 8043.0                                              0
# 8105.0                                             40
# 8142.0                                              0
# 8362.0                                              4
# 8409.0                                              4
#
#                           activitePrincipaleRegistreMetiersEtablissement  \
# codeCommuneEtablissement
# 8043.0                                                                 0
# 8105.0                                                                 0
# 8142.0                                                                 0
# 8362.0                                                                 0
# 8409.0                                                                 0
#
#                           dateDernierTraitementEtablissement  ...  dateDebut  \
# codeCommuneEtablissement                                      ...
# 8043.0                                                     1  ...          1
# 8105.0                                                    62  ...         62
# 8142.0                                                     1  ...          1
# 8362.0                                                     8  ...          8
# 8409.0                                                     8  ...          9
#
#                           etatAdministratifEtablissement  \
# codeCommuneEtablissement
# 8043.0                                                 1
# 8105.0                                                62
# 8142.0                                                 1
# 8362.0                                                 8
# 8409.0                                                 9
#
#                           enseigne1Etablissement  enseigne2Etablissement  \
# codeCommuneEtablissement
# 8043.0                                         0                       0
# 8105.0                                         0                       0
# 8142.0                                         0                       0
# 8362.0                                         0                       0
# 8409.0                                         0                       0
#
#                           enseigne3Etablissement  \
# codeCommuneEtablissement
# 8043.0                                         0
# 8105.0                                         0
# 8142.0                                         0
# 8362.0                                         0
# 8409.0                                         0
#
#                           denominationUsuelleEtablissement  \
# codeCommuneEtablissement
# 8043.0                                                   0
# 8105.0                                                   0
# 8142.0                                                   0
# 8362.0                                                   0
# 8409.0                                                   0
#
#                           activitePrincipaleEtablissement  \
# codeCommuneEtablissement
# 8043.0                                                  1
# 8105.0                                                 62
# 8142.0                                                  1
# 8362.0                                                  8
# 8409.0                                                  9
#
#                           nomenclatureActivitePrincipaleEtablissement  \
# codeCommuneEtablissement
# 8043.0                                                              1
# 8105.0                                                             62
# 8142.0                                                              1
# 8362.0                                                              8
# 8409.0                                                              9
#
#                           caractereEmployeurEtablissement  codeDepartement
# codeCommuneEtablissement
# 8043.0                                                  1                1
# 8105.0                                                 62               62
# 8142.0                                                  1                1
# 8362.0                                                  8                8
# 8409.0                                                  9                9
#
# [5 rows x 80 columns]

# %%
list_Latitude = list()
list_Longitude = list()
list_codeCommune = list()
def find_LL():
    for val in df_selection2.index:
        df_latitude_longitude = gps.loc[gps['code_insee'] == val]
        list_Latitude.append(df_latitude_longitude.iloc[0,11])
        list_Longitude.append(df_latitude_longitude.iloc[0,12])
        list_codeCommune.append(val)

# %%
find_LL()

# %% [markdown]
# ### Function Distance

# %%
 
from math import sin, cos, acos, pi
 
#############################################################################
def dms2dd(d, m, s):
    """Convertit un angle "degrés minutes secondes" en "degrés décimaux"
    """
    return d + m/60 + s/3600
 
#############################################################################
def dd2dms(dd):
    """Convertit un angle "degrés décimaux" en "degrés minutes secondes"
    """
    d = int(dd)
    x = (dd-d)*60
    m = int(x)
    s = (x-m)*60
    return d, m, s
 
#############################################################################
def deg2rad(dd):
    """Convertit un angle "degrés décimaux" en "radians"
    """
    return dd/180*pi
 
#############################################################################
def rad2deg(rd):
    """Convertit un angle "radians" en "degrés décimaux"
    """
    return rd/pi*180
 
#############################################################################
def distanceGPS(latA, longA, latB, longB):
    """Retourne la distance en mètres entre les 2 points A et B connus grâce à
       leurs coordonnées GPS (en radians).
    """
    # Rayon de la terre en mètres (sphère IAG-GRS80)
    RT = 6378137
    # angle en radians entre les 2 points
    S = acos(sin(latA)*sin(latB) + cos(latA)*cos(latB)*cos(abs(longB-longA)))
    # distance entre les 2 points, comptée sur un arc de grand cercle
    return S*RT
 
#############################################################################

list_final_commune = list()
list_final_dist = list()

for i in range(len(list_Latitude)):
    try:
        # cooordonnées GPS en radians du 1er point (ici, mairie de Tours)
        latA = deg2rad(float(lalitude)) # Nord
        longA = deg2rad(float(longitude)) # Est

        # cooordonnées GPS en radians du 2ème point (ici, mairie de Limoges)
        latB = deg2rad(float(list_Latitude[i])) # Nord
        longB = deg2rad(float(list_Longitude[i])) # Est

        dist = distanceGPS(latA, longA, latB, longB)
        #list_final_commune.append(int(dist))
        
        if int(dist)/1000 < 30:
            list_final_commune.append(list_codeCommune[i])
            list_final_dist.append(int(dist))
    except:
        #list_final_commune.append('nan')
        pass

# %%
list_final_departement = list()
for val in list_final_commune:
    df_depart = gps.loc[gps['code_insee'] == val]
    list_final_departement.append(df_depart.iloc[0,4])
    #print(list_final_departement[-1])

# %% [markdown]
# ### French map : Use Librairie PYGAL

# %%
def chart():
    save = list()
    fr_chart = pygal.maps.fr.Departments(style=custom_style,height=450)    #,legend_at_bottom=True)
    fr_chart.title = 'Concurrences'
    for x in list_final_departement:
        if x not in save:
            fr_chart.add('Concurence < 30', {x : list_final_departement.count(x)})
            save.append(x)
    fr_chart.render_in_browser() # Exporte to Browser

# %%
chart()
# Out:
# file:///var/folders/v3/6rms4ljn2dzdln_l8746trf00000gn/T/tmppqd30dg0.html

# %% [markdown]
# ### Print Commune

# %%
def print_concurrence():
    print("Commune à moins de 30 Km :")
    for i in range(len(list_final_commune)):
        print("\t Commune : %s, Distance : %s Km" %(list_final_commune[i],int(list_final_dist[i]/1000)))

# %%
print_concurrence()
# Out:
# Commune à moins de 30 Km :
# 	 Commune : 25031.0, Distance : 16 Km
# 	 Commune : 25043.0, Distance : 18 Km
# 	 Commune : 25048.0, Distance : 19 Km
# 	 Commune : 25057.0, Distance : 12 Km
# 	 Commune : 25196.0, Distance : 16 Km
# 	 Commune : 25230.0, Distance : 15 Km
# 	 Commune : 25284.0, Distance : 11 Km
# 	 Commune : 25304.0, Distance : 22 Km
# 	 Commune : 25367.0, Distance : 21 Km
# 	 Commune : 25388.0, Distance : 13 Km
# 	 Commune : 25539.0, Distance : 18 Km
# 	 Commune : 25547.0, Distance : 13 Km
# 	 Commune : 25580.0, Distance : 18 Km
# 	 Commune : 25614.0, Distance : 13 Km
# 	 Commune : 70310.0, Distance : 28 Km
# 	 Commune : 90010.0, Distance : 0 Km
# 	 Commune : 90033.0, Distance : 17 Km
# 	 Commune : 90075.0, Distance : 3 Km
# 	 Commune : 90099.0, Distance : 3 Km
